# %% [markdown]
# ## INNER JOIN
#
# Penggabungan yang berdasarkan column key yang sama, artinya baris dari kedua atau lebih tabel akan dibandingkan untuk mengecek baris - baris mana saja yang cocok satu sama lain berdasarkan kondisi JOIN yang ditentukan.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Inner Join merupakan irisan kedua tabel_1 dan tabel_2 ya!

# %%
sql(
"""
SELECT orders.*, order_details.*  FROM orders
INNER JOIN order_details
ON orders.order_id=order_details.order_id
LIMIT 5;
""")

# Latihan hubungkan products dengan order_details
# Out:
#    order_id customer_id  employee_id  order_date required_date shipped_date  \
# 0     10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 1     10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 2     10248       VINET            5  1996-07-04    1996-08-01   1996-07-16
# 3     10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
# 4     10249       TOMSP            6  1996-07-05    1996-08-16   1996-07-10
#
#    ship_via  freight                  ship_name        ship_address ship_city  \
# 0         3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye     Reims
# 1         3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye     Reims
# 2         3    32.38  Vins et alcools Chevalier  59 rue de l'Abbaye     Reims
# 3         1    11.61         Toms Spezialitäten       Luisenstr. 48   Münster
# 4         1    11.61         Toms Spezialitäten       Luisenstr. 48   Münster
#
# ...

# %% [markdown]
# INNER JOIN akan mencocokkan key kolom tabel_1 dengan key kolom lawannya, jika value dari key kolom sama - sama ada di kedua tabel , maka baris itu akan dikembalikan sebagai hasil query dan membentuk satu tabel yang berisi seluruh kolom dari kedua tabel, sedangkan jika value key kolom hanya terdapat di satu kolom, maka baris ini tidak akan ditampilkan.

# %% [markdown]
# > Perlu diperhatikan jika menampilkan kolom dengan nama yang sama di kedua tabel, maka pada bagian Select, tidak bisa hanya mengetikkan nama kolom saja, tetapi juga harus didahului oleh prefix nama tabel dimana kolom itu berasal untuk menghindari error karena ambiguitas.

# %%
# Sekarang hanya ambil ship_city, unit_price, quntity, discount, freight
# Coba disini!

# %% [markdown]
# **KESIMPULAN**
#
# 1. Pada tahap awal kita menggunakan INNER JOIN untuk menggabungkan keseluruhan kolom yang dimiliki oleh kedua tabel tersebut.
# 2. Selanjutnya, kita menerapkan INNER JOIN dengan menggunakan prefix nama tabel untuk memilih kolom-kolom mana saja yang akan ditampilkan pada tabel hasil penggabungan.

# %% [markdown]
# <a href="#Daftar-Pustaka">Keatas</a>
