# %% [markdown]
# # Pendahuluan
#
# Selamat datang, dan mari kita mempelajari bagaimana melakukan persiapan data serta proses manipulasi berdasarkan data Covid-19 yang didapatkan dalam API. Perhatikan berikut ini.
#
# ```python
# # Persiapkan library yang digunakan
# import pandas as pd
# import numpy as np
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```

# %%
# Silahkan dicoba disini

# %% [markdown]
# ## Persiapkan data
#
# Disini kita akan melakukan persiapan data yang kita gunakan.

# %%
# Penarikan data dari link api
url = "https://storage.googleapis.com/dqlab-dataset/covid2019-api-herokuapp-v2.json"
df_json = pd.read_json(url)
df_json.head(3)
# Out:
#                                                 data          dt          ts
# 0  {'location': 'US', 'confirmed': 3363056, 'deat...  07-14-2020  1594684800
# 1  {'location': 'Brazil', 'confirmed': 1884967, '...  07-14-2020  1594684800
# 2  {'location': 'India', 'confirmed': 906752, 'de...  07-14-2020  1594684800

# %%
df = pd.DataFrame(df_json['data'].to_list())
df.head()
# Out:
#   location  confirmed  deaths  recovered   active
# 0       US    3363056  135605    1031939  2253244
# 1   Brazil    1884967   72833    1291251   520883
# 2    India     906752   23727     571460   311565
# 3   Russia     732547   11422     503168   217957
# 4     Peru     330123   12054     221008    97061

# %% [markdown]
# ## Tahapan Analisa 1
#
# **SOAL NOMOR 1A**
#
# 1. Ada berapakah lokasi yang unik dalam dataset?
# 2. Apakah ada data yang null?
# 3. Berapakah jumlah confirmed, deaths, recovered dan active di Indonesia?
# 4. Bagaimana menambahkan kolom dt dalam dataframe yang kita miliki, dan cek ada tanggal berapa saja?

# %%
print("Jumlah lokasi yang unik ada %i lokasi"% .................)
print("Data memiliki null? %s"% .................)
print("Data memiliki null? \n%s"% .................)
# Out:
# Jumlah lokasi yang unik ada 188 lokasi
# Data memiliki null? False
# Data memiliki null?
#      location  confirmed  deaths  recovered  active
# 25  Indonesia      76981    3656      36689   36636

# %%
# Menambahkan kolom time
.....................
df.head()
# Out:
#   location  confirmed  deaths  recovered   active        time
# 0       US    3363056  135605    1031939  2253244  07-14-2020
# 1   Brazil    1884967   72833    1291251   520883  07-14-2020
# 2    India     906752   23727     571460   311565  07-14-2020
# 3   Russia     732547   11422     503168   217957  07-14-2020
# 4     Peru     330123   12054     221008    97061  07-14-2020

# %%
# Check data tanggal yang dimiliki
..................
# Out:
# ['07-14-2020']

# %% [markdown]
# **SOAL NOMOR 1B**
#
# 1. Siapakah 5 negara dengan confirmed dan recovered terkecil?
# 2. Siapakah 5 negara dengan angka deaths rendah sedangkan recoverednya tinggi?
# 3. Siapakah 5 negara dengan angka active tinggi sedangkan confirmednya rendah?

# %%
..........................
# Out:
#                   location  confirmed  deaths  recovered  active
# 187             MS Zaandam          9       2          0       7
# 186         Western Sahara         10       1          8       1
# 185       Papua New Guinea         11       0          8       3
# 184               Holy See         12       0         12       0
# 183  Saint Kitts and Nevis         17       0         15       2

# %%
..........................
# Out:
#      location  confirmed  deaths  recovered  active
# 135    Uganda       1029       0        977      52
# 155   Vietnam        373       0        352      21
# 162  Mongolia        243       0        204      39
# 164  Cambodia        165       0        133      32
# 163   Eritrea        232       0        107     125

# %%
..........................
# Out:
#          location  confirmed  deaths  recovered   active
# 0              US    3363056  135605    1031939  2253244
# 1          Brazil    1884967   72833    1291251   520883
# 2           India     906752   23727     571460   311565
# 7  United Kingdom     291691   44915       1384   245392
# 3          Russia     732547   11422     503168   217957

# %% [markdown]
# ## Tahapan Analisa 2
#
# **SOAL NOMOR 2**
#
# 1. Hitung mean, median, dan statistik lainnya dalam data?
# 2. Buatlah boxplot untuk mengetahui outlier?

# %%
.............
# Out:
#           confirmed         deaths     recovered        active
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02
# mean   6.969835e+04    3048.095745  3.860303e+04  2.835432e+04
# std    2.962244e+05   12619.784337  1.378381e+05  1.715364e+05
# min    9.000000e+00       0.000000  0.000000e+00  0.000000e+00
# 25%    8.752500e+02      15.000000  4.387500e+02  1.225000e+02
# 50%    4.638500e+03      81.500000  2.279000e+03  1.191000e+03
# 75%    3.299925e+04     651.000000  1.741150e+04  7.972000e+03
# max    3.363056e+06  135605.000000  1.291251e+06  2.253244e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   188 non-null    object
#  1   confirmed  188 non-null    int64
#  2   deaths     188 non-null    int64
#  3   recovered  188 non-null    int64
#  4   active     188 non-null    int64
#  5   time       188 non-null    object
# dtypes: int64(4), object(2)
# memory usage: 8.9+ KB

# %%
for i in ...................:
  plt.figure()
  sns.boxplot(..............)
  plt.show()

# %% [markdown]
# ## Tahapan Analisa 3
#
# **SOAL NOMOR 3**
#
# Silahkan atasi outlier data yang dimiliki.

# %%
Q1 = ..................
Q3 = ..................
IQR = Q3 - Q1
maximum = Q3 + (1.5*IQR)
print('Nilai Maximum dari masing-masing Variable adalah: ')
print(maximum)
minimum = Q1 - (1.5*IQR)
print('\nNilai Minimum dari masing-masing Variable adalah: ')
print(minimum)
# Out:
# Nilai Maximum dari masing-masing Variable adalah:
# confirmed    81185.250
# deaths        1605.000
# recovered    42870.625
# active       19746.250
# dtype: float64
#
# Nilai Minimum dari masing-masing Variable adalah:
# confirmed   -47310.750
# deaths        -939.000
# recovered   -25020.375
# active      -11651.750
# dtype: float64

# %%
more_than = (df > maximum)
lower_than = (df < minimum)
df = df.....(.........................)
df = df.....(.........................)
print('\nPersebaran data setelah ditangani Outlier: ')
df.describe()
# Out:
# Persebaran data setelah ditangani Outlier:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#           confirmed         deaths     recovered        active
# count  1.880000e+02     188.000000  1.880000e+02  1.880000e+02
# mean   6.969835e+04    3048.095745  3.860303e+04  2.835432e+04
# std    2.962244e+05   12619.784337  1.378381e+05  1.715364e+05
# min    9.000000e+00       0.000000  0.000000e+00  0.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   location   188 non-null    object
#  1   confirmed  188 non-null    float64
#  2   deaths     188 non-null    int64
#  3   recovered  188 non-null    float64
#  4   active     188 non-null    float64
#  5   time       188 non-null    object
# dtypes: float64(3), int64(1), object(2)
# memory usage: 8.9+ KB

# %%
for i in .....................:
  plt.figure()
  sns.boxplot(................)
  plt.show()

# %%
df.head()
# Out:
#   location  confirmed  deaths  recovered    active        time
# 0       US   81185.25    1605  42870.625  19746.25  07-14-2020
# 1   Brazil   81185.25    1605  42870.625  19746.25  07-14-2020
# 2    India   81185.25    1605  42870.625  19746.25  07-14-2020
# 3   Russia   81185.25    1605  42870.625  19746.25  07-14-2020
# 4     Peru   81185.25    1605  42870.625  19746.25  07-14-2020
